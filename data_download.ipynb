# %%
"""#2026 districts
import geopandas as gpd

sa2 = gpd.read_file("/Users/tazeenatif/Downloads/SA2_2026_AUST_SHP_GDA2020/SA2_2026_AUST_GDA2020.shp")
print(sa2.head(10))

sa2.plot(figsize = (10, 10))

print("VIC SA2 REGIONS")
vic_sa2 = sa2[sa2["STE_NAME26"] == "Victoria"].copy()
print(vic_sa2.head(10))"""

#2021 districts
import pandas as pd
sa2_2021 = pd.read_excel('/Users/tazeenatif/Downloads/SA2_2021_AUST.xlsx')
print(sa2_2021.head(10))

print("VIC SA2 REGIONS 2021")
vic_sa2_21 = sa2_2021[sa2_2021["STATE_NAME_2021"] == "Victoria"].copy()
print(vic_sa2_21.head(10))

sa2districts = vic_sa2_21["SA2_NAME_2021"].unique()
print(sa2districts)
